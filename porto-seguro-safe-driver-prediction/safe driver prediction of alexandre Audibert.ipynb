# %%
import pandas as pd 
import numpy as np

# %%
# Importer un CSV
df = pd.read_csv("C:/Users/Audb/Documents/GitHub/Dataset/porto-seguro-safe-driver-prediction/train.csv")

# %%
df
# Out:
#              id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0             7       0          2              2          5              1
# 1             9       0          1              1          7              0
# 2            13       0          5              4          9              1
# 3            16       0          0              1          2              0
# 4            17       0          0              2          0              1
# ...         ...     ...        ...            ...        ...            ...
# 595207  1488013       0          3              1         10              0
# 595208  1488016       0          5              1          3              0
# 595209  1488017       0          1              1         10              0
# 595210  1488021       0          5              2          3              1
# 595211  1488027       0          0              1          8              0
#
# ...
