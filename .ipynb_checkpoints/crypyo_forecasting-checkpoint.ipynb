# %%
import sys; print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]

# %%
import pandas as pd 
import numpy as np
from datetime import datetime
import time

# %%
# Importer un CSV
train = pd.read_csv("D:/GitHub/Dataset/g-research-crypto-forecasting/train.csv")

# %%
ad = pd.read_csv("D:/GitHub/Dataset/g-research-crypto-forecasting/asset_details.csv")

# %%
train_2020 = train.loc[(train['timestamp'] >= 1577873958) & (train['timestamp'] < 1609455600)]

# %%
train_2020.shape
# Out:
# (6919623, 10)

# %%
train
# Out:
#            timestamp  Asset_ID  Count          Open          High  \
# 0         1514764860         2   40.0   2376.580000   2399.500000
# 1         1514764860         0    5.0      8.530000      8.530000
# 2         1514764860         1  229.0  13835.194000  14013.800000
# 3         1514764860         5   32.0      7.659600      7.659600
# 4         1514764860         7    5.0     25.920000     25.920000
# ...              ...       ...    ...           ...           ...
# 24236801  1632182400         9  775.0    157.181571    157.250000
# 24236802  1632182400        10   34.0   2437.065067   2438.000000
# 24236803  1632182400        13  380.0      0.091390      0.091527
# 24236804  1632182400        12  177.0      0.282168      0.282438
# 24236805  1632182400        11   48.0    232.695000    232.800000
#
#                    Low         Close        Volume          VWAP    Target
# 0          2357.140000   2374.590000  1.923301e+01   2373.116392 -0.004218
# ...

# %%
ad
# Out:
#     Asset_ID    Weight        Asset_Name
# 0          2  2.397895      Bitcoin Cash
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 3          5  1.386294            EOS.IO
# 4          7  2.079442  Ethereum Classic
# 5          6  5.894403          Ethereum
# 6          9  2.397895          Litecoin
# 7         11  1.609438            Monero
# 8         13  1.791759              TRON
# 9         12  2.079442           Stellar
# 10         3  4.406719           Cardano
# 11         8  1.098612              IOTA
# 12        10  1.098612             Maker
# 13         4  3.555348          Dogecoin

# %%
train['date'] = train['timestamp'].to_period(freq='H')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15768/1554506075.py in <module>
# ----> 1 train['date'] = train['timestamp'].to_period(freq='H')
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in to_period(self, freq, copy)
#    5369
#    5370         if not isinstance(self.index, DatetimeIndex):
# -> 5371             raise TypeError(f"unsupported Type {type(self.index).__name__}")
#    5372         new_index = self.index.to_period(freq=freq)
#    5373         return self._constructor(new_values, index=new_index).__finalize__(
#
# TypeError: unsupported Type RangeIndex

# %%
train.dtypes
# Out:
# timestamp      int64
# Asset_ID       int64
# Count        float64
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# VWAP         float64
# Target       float64
# dtype: object

# %%
train['date'] = datetime.fromtimestamp(train['timestamp'].strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15768/1934675131.py in <module>
# ----> 1 train['date'] = datetime.fromtimestamp(train['timestamp'].strftime('%Y-%m-%d %H:%M:%S'))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strftime'

# %%
# auxiliary function, from datetime to timestamp
totimestamp = lambda s: np.int32(time.mktime(datetime.strptime(s, "%d/%m/%Y").timetuple()))

# %%
 train['date'] = totimestamp(train['timestamp'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15768/2124894551.py in <module>
# ----> 1 train['date'] = totimestamp(train['timestamp'])
#
# ~\AppData\Local\Temp/ipykernel_15768/1057417228.py in <lambda>(s)
#       1 # auxiliary function, from datetime to timestamp
# ----> 2 totimestamp = lambda s: np.int32(time.mktime(datetime.strptime(s, "%d/%m/%Y").timetuple()))
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
 train['date']  = train[['timestamp']].applymap(lambda x: time.localtime(x))
train_prep2 = train_prep1[['timestamp']].applymap(lambda x: time.strftime("%Y-%m-%d %H:%M:%S", x))
train['timestamp'] = train_prep2

# %%
train
# Out:
#            timestamp  Asset_ID  Count          Open          High  \
# 0         1514764860         2   40.0   2376.580000   2399.500000
# 1         1514764860         0    5.0      8.530000      8.530000
# 2         1514764860         1  229.0  13835.194000  14013.800000
# 3         1514764860         5   32.0      7.659600      7.659600
# 4         1514764860         7    5.0     25.920000     25.920000
# ...              ...       ...    ...           ...           ...
# 24236801  1632182400         9  775.0    157.181571    157.250000
# 24236802  1632182400        10   34.0   2437.065067   2438.000000
# 24236803  1632182400        13  380.0      0.091390      0.091527
# 24236804  1632182400        12  177.0      0.282168      0.282438
# 24236805  1632182400        11   48.0    232.695000    232.800000
#
#                    Low         Close        Volume          VWAP    Target  \
# 0          2357.140000   2374.590000  1.923301e+01   2373.116392 -0.004218
# ...
